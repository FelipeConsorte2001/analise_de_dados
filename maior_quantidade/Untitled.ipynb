# %%
import pandas as pd
df = pd.read_csv('IPTU_Part_01_750K.csv',encoding="ISO-8859-1", sep=';')
df_parte2 = pd.read_csv('IPTU_Part_02_750K.csv',encoding="ISO-8859-1", sep=';')
df_parte3 = pd.read_csv('IPTU_Part_03_970K.csv',encoding="ISO-8859-1", sep=';')
df_parte4 = pd.read_csv('IPTU_Part_04_750K.csv',encoding="ISO-8859-1", sep=';')
df_parte5 = pd.read_csv('IPTU_Part_05_750K.csv',encoding="ISO-8859-1", sep=';')
df = df.append(df_parte2)
df = df.append(df_parte3)
df = df.append(df_parte4)
df = df.append(df_parte5)
# Out:
#        NUMERO DO CONTRIBUINTE  ANO DO EXERCICIO  NUMERO DA NL  \
# 0                0010030001-4              2016             1
# 1                0010030002-2              2016             1
# 2                0010030003-0              2016             1
# 3                0010030004-9              2016             1
# 4                0010030005-7              2016             1
# ...                       ...               ...           ...
# 130025           3101180238-1              2016             1
# 130026           3101180239-1              2016             1
# 130027           3101180240-3              2016             1
# 130028           3101190001-4              2016             1
# 130029           3101200001-7              2016             1
#
#        DATA DO CADASTRAMENTO  TIPO DE CONTRIBUINTE 1  \
# 0                 16/01/2016     PESSOA FISICA (CPF)
# 1                 16/01/2016     PESSOA FISICA (CPF)
# 2                 16/01/2016     PESSOA FISICA (CPF)
# 3                 16/01/2016     PESSOA FISICA (CPF)
# 4                 16/01/2016     PESSOA FISICA (CPF)
# ...                      ...                     ...
# 130025            16/01/2016     PESSOA FISICA (CPF)
# 130026            16/01/2016     PESSOA FISICA (CPF)
# 130027            16/01/2016     PESSOA FISICA (CPF)
# 130028            16/01/2016  PESSOA JURIDICA (CNPJ)
# 130029            16/01/2016  PESSOA JURIDICA (CNPJ)
#
#                       NOME DO CONTRIBUINTE 1 TIPO DE CONTRIBUINTE 2  \
# 0                            MARCIO MOURCHED                    NaN
# 1                            MARCIO MOURCHED                    NaN
# 2                            MARCIO MOURCHED                    NaN
# 3             AUGUSTO CESAR DE MATTOS JUNIOR                    NaN
# 4             AUGUSTO CESAR DE MATTOS JUNIOR                    NaN
# ...                                      ...                    ...
# 130025                         CECILIA OTUKA                    NaN
# 130026  JOSE ESTANISLAU CAMPOS MACHADO FILHO                    NaN
# 130027                        DOUGLAS MACEDO    PESSOA FISICA (CPF)
# 130028                   ESTADO DE SAO PAULO                    NaN
# 130029                   ESTADO DE SAO PAULO                    NaN
#
#               NOME DO CONTRIBUINTE 2 NUMERO DO CONDOMINIO CODLOG DO IMOVEL  \
# 0                                NaN                 00-0          03812-1
# 1                                NaN                 00-0          03812-1
# 2                                NaN                 00-0          03812-1
# 3                                NaN                 00-0          03812-1
# 4                                NaN                 00-0          03812-1
# ...                              ...                  ...              ...
# 130025                           NaN                42614          02235-7
# 130026                           NaN                42614          02235-7
# 130027  JOICE FERNANDA PAIXAO MACEDO                42614          02235-7
# 130028                           NaN                 00-0          19137-0
# 130029                           NaN                 00-0          01041-3
#
#         ... ANO DA CONSTRUCAO CORRIGIDO  QUANTIDADE DE PAVIMENTOS  \
# 0       ...                        1924                         1
# 1       ...                        1944                         1
# 2       ...                        1965                         2
# 3       ...                        1944                         1
# 4       ...                        1944                         1
# ...     ...                         ...                       ...
# 130025  ...                        1978                         5
# 130026  ...                        1978                         5
# 130027  ...                        1978                         5
# 130028  ...                           0                         0
# 130029  ...                           0                         0
#
#        TESTADA PARA CALCULO      TIPO DE USO DO IMOVEL  \
# 0                        13                       Loja
# 1                         6                       Loja
# 2                      7,85                       Loja
# 3                      6,05                       Loja
# 4                       6,7                       Loja
# ...                     ...                        ...
# 130025                    0  Apartamento em condomínio
# 130026                    0  Apartamento em condomínio
# 130027                    0  Apartamento em condomínio
# 130028                    0                    Terreno
# 130029                  500                    Terreno
#
#            TIPO DE PADRAO DA CONSTRUCAO TIPO DE TERRENO  \
# 0       Comercial horizontal - padrão B      De esquina
# 1       Comercial horizontal - padrão B          Normal
# 2       Comercial horizontal - padrão B          Normal
# 3       Comercial horizontal - padrão B          Normal
# 4       Comercial horizontal - padrão B          Normal
# ...                                 ...             ...
# 130025  Residencial vertical - padrão B      De esquina
# 130026  Residencial vertical - padrão B      De esquina
# 130027  Residencial vertical - padrão B      De esquina
# 130028                          TERRENO      De esquina
# 130029                          TERRENO          Normal
#
#         FATOR DE OBSOLESCENCIA ANO DE INICIO DA VIDA DO CONTRIBUINTE  \
# 0                          0,2                                  1963
# 1                          0,2                                  1963
# 2                         0,37                                  1963
# 3                          0,2                                  1963
# 4                          0,2                                  1963
# ...                        ...                                   ...
# 130025                    0,26                                  1985
# 130026                    0,26                                  1985
# 130027                    0,26                                  1985
# 130028                       0                                  1988
# 130029                       0                                  1988
#
#         MES DE INICIO DA VIDA DO CONTRIBUINTE  FASE DO CONTRIBUINTE
# 0                                           1                     0
# 1                                           1                     0
# 2                                           1                     0
# 3                                           1                     0
# 4                                           1                     0
# ...                                       ...                   ...
# 130025                                      1                     0
# 130026                                      1                     0
# 130027                                      1                     0
# 130028                                      1                     0
# 130029                                      1                     0
#
# [3349769 rows x 33 columns]

# %%
total = df['BAIRRO DO IMOVEL'].value_counts()
display(total)
# Out:
# TATUAPE                   25729
# BELA VISTA                22141
# PERDIZES                  21221
# SAUDE                     20909
# SANTANA                   18996
#                           ...
# SAUDE  -  RESIDENCIAL         1
# BL B JD PREVIDENCIA           1
# BL JATOBA VILA DAS MER        1
# VLIA DAS MERCES               1
# ENTR.P/R.WILSON HAHRA         1
# Name: BAIRRO DO IMOVEL, Length: 88494, dtype: int64
